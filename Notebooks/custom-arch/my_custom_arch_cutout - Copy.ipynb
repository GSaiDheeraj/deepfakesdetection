# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
import math
import copy
import numpy as np

from keras.models import Sequential, Model
from keras.layers import Input, Dense, Flatten, Dropout, Activation, Lambda, Permute, Reshape
from keras.layers import Convolution2D, ZeroPadding2D, MaxPooling2D
from keras_vggface.vggface import VGGFace
from keras_vggface import utils
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator

from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob
import pandas as pd
import cv2
import scipy.misc
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
from random_eraser import get_random_eraser

# %% [markdown]
# Augmented data

# %%
base_path = "C:/Users/saidh/Downloads/archive/real_vs_fake/real-vs-fake/"


batch_size=64

image_gen1 =  ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False,  # randomly flip images
        preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=False))

train_flow= image_gen1.flow_from_directory(
    base_path + 'train/',
    target_size = (224, 224),
    batch_size = batch_size,
    class_mode ='binary'
)

valid_flow = image_gen1.flow_from_directory(
    base_path + 'valid/',
    target_size = (224, 224),
    batch_size = batch_size,
    class_mode = 'binary'
)
test_flow = image_gen1.flow_from_directory(
    base_path + 'test/',
    target_size = (224, 224),
    batch_size = 1,
    shuffle = False,
    class_mode ='binary'
)
# Out:
# Found 100000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.
# Found 20000 images belonging to 2 classes.

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential
from keras.layers import BatchNormalization
# """
#     Propsoed CNN architecture.
    
# """

# model = Sequential()

# # Pamameters Initialization
# input_shape = (224,224,3)
# activation = 'relu'
# padding = 'same'
# droprate = 0.1
# epsilon = 0.001

# model = Sequential()
# model.add(BatchNormalization(input_shape=input_shape))
# model.add(Conv2D(filters=16, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))


# model.add(Conv2D(filters=32, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))
# model.add(Dropout(droprate))

# model.add(Conv2D(filters=64, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))
# model.add(Dropout(droprate))

# model.add(Conv2D(filters =128, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))
# model.add(Dropout(droprate))

# model.add(Conv2D(filters=256, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))
# model.add(Dropout(droprate))

# model.add(Conv2D(filters=512, kernel_size=3, activation=activation, padding=padding))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization(epsilon=epsilon))
# #model.add(Dropout(droprate))

# model.add(GlobalAveragePooling2D())
# #model.add(Flatten())
# #model.add(Dense(256, kernel_initializer='glorot_normal', activation='relu'))
# #model.add(Dropout(0.5))
          
# #model.add(Dense(128, kernel_initializer='glorot_normal', activation='relu'))
# #model.add(Dropout(0.5))
# #model.add(Dropout(droprate))
# model.add(Dense(1, activation='sigmoid'))

# model.summary() # Summary of the architecture
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 224, 224, 3)       12
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 16)      0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 112, 112, 16)      64
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 56, 56, 32)        128
# _________________________________________________________________
# dropout (Dropout)            (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       73856
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 14, 14, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       295168
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 7, 7, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 7, 7, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 7, 7, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 3, 3, 512)         0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 3, 3, 512)         2048
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 1,577,325
# Trainable params: 1,575,303
# Non-trainable params: 2,022
# _________________________________________________________________

# %%
# input_shape = (224,224,3)
# epsilon=0.001
# activation = 'relu'
# padding = 'same'
# droprate = 0.1


# model = Sequential()
# model.add(BatchNormalization(input_shape=input_shape))
# model.add(Conv2D(filters=16, kernel_size=3, activation= 'relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())

# model.add(Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# # model.add(Dropout(0.1))

# model.add(Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))

# model.add(Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))

# model.add(Conv2D(filters=256, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))

# model.add(Conv2D(filters=512, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))

# model.add(Conv2D(filters=1024, kernel_size=3, activation='relu', padding='same'))
# model.add(MaxPooling2D(pool_size=2))
# model.add(BatchNormalization())
# model.add(Dropout(0.1))

# model.add(Flatten())

# model.add(Dense(1, activation='sigmoid'))

# model.summary()

# %%
import tensorflow as tf
from typing import List, Tuple
from keras.models import Model
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.initializers import glorot_uniform

# %%
def identity_block(X: tf.Tensor, level: int, block: int, filters: List[int]) -> tf.Tensor:
    """
    Creates an identity block (see figure 3.1 from readme)

    Input:
        X - input tensor of shape (m, height_prev, width_prev, chan_prev)
        level - integer, one of the 5 levels that our networks is conceptually divided into (see figure 3.1 in the readme file)
              - level names have the form: conv2_x, conv3_x ... conv5_x
        block - each conceptual level has multiple blocks (1 identity and several convolutional blocks)
                block is the number of this block within its conceptual layer
                i.e. first block from level 2 will be named conv2_1
        filters - a list on integers, each of them defining the number of filters in each convolutional layer

    Output:
        X - tensor (m, height, width, chan)
    """

    # layers will be called conv{level}_iden{block}_{convlayer_number_within_block}'
    conv_name = f'conv{level}_{block}' + '_{layer}_{type}'

    # unpack number of filters to be used for each conv layer
    f1, f2, f3 = filters

    # the shortcut branch of the identity block
    # takes the value of the block input
    X_shortcut = X

    # first convolutional layer (plus batch norm & relu activation, of course)
    X = Conv2D(filters=f1, kernel_size=(1, 1), strides=(1, 1),
               padding='valid', name=conv_name.format(layer=1, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=1, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=1, type='relu'))(X)

    # second convolutional layer
    X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1),
               padding='same', name=conv_name.format(layer=2, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=2, type='bn'))(X)
    X = Activation('relu')(X)

    # third convolutional layer
    X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1),
               padding='valid', name=conv_name.format(layer=3, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=3, type='bn'))(X)

    # add shortcut branch to main path
    X = Add()([X, X_shortcut])

    # relu activation at the end of the block
    X = Activation('relu', name=conv_name.format(layer=3, type='relu'))(X)

    return X

# %%
def convolutional_block(X: tf.Tensor, level: int, block: int, filters: List[int], s: Tuple[int,int,int]=(2, 2)) -> tf.Tensor:
    """
    Creates a convolutional block (see figure 3.1 from readme)

    Input:
        X - input tensor of shape (m, height_prev, width_prev, chan_prev)
        level - integer, one of the 5 levels that our networks is conceptually divided into (see figure 3.1 in the readme file)
              - level names have the form: conv2_x, conv3_x ... conv5_x
        block - each conceptual level has multiple blocks (1 identity and several convolutional blocks)
                block is the number of this block within its conceptual layer
                i.e. first block from level 2 will be named conv2_1
        filters - a list on integers, each of them defining the number of filters in each convolutional layer
        s   - stride of the first layer;
            - a conv layer with a filter that has a stride of 2 will reduce the width and height of its input by half

    Output:
        X - tensor (m, height, width, chan)
    """

    # layers will be called conv{level}_{block}_{convlayer_number_within_block}'
    conv_name = f'conv{level}_{block}' + '_{layer}_{type}'

    # unpack number of filters to be used for each conv layer
    f1, f2, f3 = filters

    # the shortcut branch of the convolutional block
    X_shortcut = X

    # first convolutional layer
    X = Conv2D(filters=f1, kernel_size=(1, 1), strides=s, padding='valid',
               name=conv_name.format(layer=1, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=1, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=1, type='relu'))(X)

    # second convolutional layer
    X = Conv2D(filters=f2, kernel_size=(3, 3), strides=(1, 1), padding='same',
               name=conv_name.format(layer=2, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=2, type='bn'))(X)
    X = Activation('relu', name=conv_name.format(layer=2, type='relu'))(X)

    # third convolutional layer
    X = Conv2D(filters=f3, kernel_size=(1, 1), strides=(1, 1), padding='valid',
               name=conv_name.format(layer=3, type='conv'),
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=conv_name.format(layer=3, type='bn'))(X)

    # shortcut path
    X_shortcut = Conv2D(filters=f3, kernel_size=(1, 1), strides=s, padding='valid',
                        name=conv_name.format(layer='short', type='conv'),
                        kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=conv_name.format(layer='short', type='bn'))(X_shortcut)

    # add shortcut branch to main path
    X = Add()([X, X_shortcut])

    # nonlinearity
    X = Activation('relu', name=conv_name.format(layer=3, type='relu'))(X)

    return X

# %%
def ResNet50(input_size: Tuple[int,int,int], classes: int) -> Model:
    """
        Builds the ResNet50 model (see figure 4.2 from readme)

        Input:
            - input_size - a (height, width, chan) tuple, the shape of the input images
            - classes - number of classes the model must learn

        Output:
            model - a Keras Model() instance
    """

    # tensor placeholder for the model's input
    X_input = Input(input_size)

    ### Level 1 ###

    # padding
    X = ZeroPadding2D((3, 3))(X_input)

    # convolutional layer, followed by batch normalization and relu activation
    X = Conv2D(filters=64, kernel_size=(7, 7), strides=(2, 2),
               name='conv1_1_1_conv',
               kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='conv1_1_1_nb')(X)
    X = Activation('relu')(X)

    ### Level 2 ###

    # max pooling layer to halve the size coming from the previous layer
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # 1x convolutional block
    X = convolutional_block(X, level=2, block=1, filters=[64, 64, 256], s=(1, 1))

    # 2x identity blocks
    X = identity_block(X, level=2, block=2, filters=[64, 64, 256])
    X = identity_block(X, level=2, block=3, filters=[64, 64, 256])

    ### Level 3 ###

    # 1x convolutional block
    X = convolutional_block(X, level=3, block=1, filters=[128, 128, 512], s=(2, 2))

    # 3x identity blocks
    X = identity_block(X, level=3, block=2, filters=[128, 128, 512])
    X = identity_block(X, level=3, block=3, filters=[128, 128, 512])
    X = identity_block(X, level=3, block=4, filters=[128, 128, 512])

    ### Level 4 ###
    # 1x convolutional block
    X = convolutional_block(X, level=4, block=1, filters=[256, 256, 1024], s=(2, 2))
    # 5x identity blocks
    X = identity_block(X, level=4, block=2, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=3, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=4, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=5, filters=[256, 256, 1024])
    X = identity_block(X, level=4, block=6, filters=[256, 256, 1024])

    ### Level 5 ###
    # 1x convolutional block
    X = convolutional_block(X, level=5, block=1, filters=[512, 512, 2048], s=(2, 2))
    # 2x identity blocks
    X = identity_block(X, level=5, block=2, filters=[512, 512, 2048])
    X = identity_block(X, level=5, block=3, filters=[512, 512, 2048])

    # Pooling layers
    X = AveragePooling2D(pool_size=(2, 2), name='avg_pool')(X)

    # Output layer
    X = Flatten()(X)
    X = Dense(1, activation='softmax', name='fc_' + str(classes),
              kernel_initializer=glorot_uniform(seed=0))(X)

    # Create model
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
model = ResNet50(input_size = (224, 224, 3), classes =2)
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1_1_1_conv (Conv2D)         (None, 112, 112, 64) 9472        zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv1_1_1_nb (BatchNormalizatio (None, 112, 112, 64) 256         conv1_1_1_conv[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 112, 112, 64) 0           conv1_1_1_nb[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 55, 55, 64)   0           activation[0][0]
# __________________________________________________________________________________________________
# conv2_1_1_conv (Conv2D)         (None, 55, 55, 64)   4160        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2_1_1_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_1_1_relu (Activation)     (None, 55, 55, 64)   0           conv2_1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_2_conv (Conv2D)         (None, 55, 55, 64)   36928       conv2_1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_1_2_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_1_2_relu (Activation)     (None, 55, 55, 64)   0           conv2_1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_3_conv (Conv2D)         (None, 55, 55, 256)  16640       conv2_1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_1_short_conv (Conv2D)     (None, 55, 55, 256)  16640       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2_1_3_bn (BatchNormalizatio (None, 55, 55, 256)  1024        conv2_1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_1_short_bn (BatchNormaliz (None, 55, 55, 256)  1024        conv2_1_short_conv[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 55, 55, 256)  0           conv2_1_3_bn[0][0]
#                                                                  conv2_1_short_bn[0][0]
# __________________________________________________________________________________________________
# conv2_1_3_relu (Activation)     (None, 55, 55, 256)  0           add[0][0]
# __________________________________________________________________________________________________
# conv2_2_1_conv (Conv2D)         (None, 55, 55, 64)   16448       conv2_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv2_2_1_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_2_1_relu (Activation)     (None, 55, 55, 64)   0           conv2_2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_2_conv (Conv2D)         (None, 55, 55, 64)   36928       conv2_2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_2_2_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_2_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 55, 55, 64)   0           conv2_2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_2_3_conv (Conv2D)         (None, 55, 55, 256)  16640       activation_1[0][0]
# __________________________________________________________________________________________________
# conv2_2_3_bn (BatchNormalizatio (None, 55, 55, 256)  1024        conv2_2_3_conv[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 55, 55, 256)  0           conv2_2_3_bn[0][0]
#                                                                  conv2_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv2_2_3_relu (Activation)     (None, 55, 55, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2_3_1_conv (Conv2D)         (None, 55, 55, 64)   16448       conv2_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv2_3_1_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_3_1_relu (Activation)     (None, 55, 55, 64)   0           conv2_3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_2_conv (Conv2D)         (None, 55, 55, 64)   36928       conv2_3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_3_2_bn (BatchNormalizatio (None, 55, 55, 64)   256         conv2_3_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 55, 55, 64)   0           conv2_3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_3_3_conv (Conv2D)         (None, 55, 55, 256)  16640       activation_2[0][0]
# __________________________________________________________________________________________________
# conv2_3_3_bn (BatchNormalizatio (None, 55, 55, 256)  1024        conv2_3_3_conv[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 55, 55, 256)  0           conv2_3_3_bn[0][0]
#                                                                  conv2_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv2_3_3_relu (Activation)     (None, 55, 55, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# conv3_1_1_conv (Conv2D)         (None, 28, 28, 128)  32896       conv2_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_1_1_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_1_1_relu (Activation)     (None, 28, 28, 128)  0           conv3_1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_2_conv (Conv2D)         (None, 28, 28, 128)  147584      conv3_1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_1_2_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_1_2_relu (Activation)     (None, 28, 28, 128)  0           conv3_1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_3_conv (Conv2D)         (None, 28, 28, 512)  66048       conv3_1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_1_short_conv (Conv2D)     (None, 28, 28, 512)  131584      conv2_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_1_3_bn (BatchNormalizatio (None, 28, 28, 512)  2048        conv3_1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_1_short_bn (BatchNormaliz (None, 28, 28, 512)  2048        conv3_1_short_conv[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 512)  0           conv3_1_3_bn[0][0]
#                                                                  conv3_1_short_bn[0][0]
# __________________________________________________________________________________________________
# conv3_1_3_relu (Activation)     (None, 28, 28, 512)  0           add_3[0][0]
# __________________________________________________________________________________________________
# conv3_2_1_conv (Conv2D)         (None, 28, 28, 128)  65664       conv3_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_2_1_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_2_1_relu (Activation)     (None, 28, 28, 128)  0           conv3_2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_2_conv (Conv2D)         (None, 28, 28, 128)  147584      conv3_2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_2_2_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_2_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 128)  0           conv3_2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_2_3_conv (Conv2D)         (None, 28, 28, 512)  66048       activation_3[0][0]
# __________________________________________________________________________________________________
# conv3_2_3_bn (BatchNormalizatio (None, 28, 28, 512)  2048        conv3_2_3_conv[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 28, 28, 512)  0           conv3_2_3_bn[0][0]
#                                                                  conv3_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_2_3_relu (Activation)     (None, 28, 28, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# conv3_3_1_conv (Conv2D)         (None, 28, 28, 128)  65664       conv3_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_3_1_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_3_1_relu (Activation)     (None, 28, 28, 128)  0           conv3_3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_2_conv (Conv2D)         (None, 28, 28, 128)  147584      conv3_3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_3_2_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_3_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 128)  0           conv3_3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_3_3_conv (Conv2D)         (None, 28, 28, 512)  66048       activation_4[0][0]
# __________________________________________________________________________________________________
# conv3_3_3_bn (BatchNormalizatio (None, 28, 28, 512)  2048        conv3_3_3_conv[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 28, 28, 512)  0           conv3_3_3_bn[0][0]
#                                                                  conv3_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_3_3_relu (Activation)     (None, 28, 28, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# conv3_4_1_conv (Conv2D)         (None, 28, 28, 128)  65664       conv3_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_4_1_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_4_1_relu (Activation)     (None, 28, 28, 128)  0           conv3_4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_2_conv (Conv2D)         (None, 28, 28, 128)  147584      conv3_4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_4_2_bn (BatchNormalizatio (None, 28, 28, 128)  512         conv3_4_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 128)  0           conv3_4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_4_3_conv (Conv2D)         (None, 28, 28, 512)  66048       activation_5[0][0]
# __________________________________________________________________________________________________
# conv3_4_3_bn (BatchNormalizatio (None, 28, 28, 512)  2048        conv3_4_3_conv[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 28, 28, 512)  0           conv3_4_3_bn[0][0]
#                                                                  conv3_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv3_4_3_relu (Activation)     (None, 28, 28, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# conv4_1_1_conv (Conv2D)         (None, 14, 14, 256)  131328      conv3_4_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_1_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_1_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_1_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_1_2_relu (Activation)     (None, 14, 14, 256)  0           conv4_1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      conv4_1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_1_short_conv (Conv2D)     (None, 14, 14, 1024) 525312      conv3_4_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_1_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_1_short_bn (BatchNormaliz (None, 14, 14, 1024) 4096        conv4_1_short_conv[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 14, 14, 1024) 0           conv4_1_3_bn[0][0]
#                                                                  conv4_1_short_bn[0][0]
# __________________________________________________________________________________________________
# conv4_1_3_relu (Activation)     (None, 14, 14, 1024) 0           add_7[0][0]
# __________________________________________________________________________________________________
# conv4_2_1_conv (Conv2D)         (None, 14, 14, 256)  262400      conv4_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_2_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_2_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_2_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_2_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 14, 14, 256)  0           conv4_2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_2_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      activation_6[0][0]
# __________________________________________________________________________________________________
# conv4_2_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_2_3_conv[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 14, 14, 1024) 0           conv4_2_3_bn[0][0]
#                                                                  conv4_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_2_3_relu (Activation)     (None, 14, 14, 1024) 0           add_8[0][0]
# __________________________________________________________________________________________________
# conv4_3_1_conv (Conv2D)         (None, 14, 14, 256)  262400      conv4_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_3_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_3_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_3_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_3_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 14, 14, 256)  0           conv4_3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_3_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      activation_7[0][0]
# __________________________________________________________________________________________________
# conv4_3_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_3_3_conv[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 14, 14, 1024) 0           conv4_3_3_bn[0][0]
#                                                                  conv4_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_3_3_relu (Activation)     (None, 14, 14, 1024) 0           add_9[0][0]
# __________________________________________________________________________________________________
# conv4_4_1_conv (Conv2D)         (None, 14, 14, 256)  262400      conv4_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_4_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_4_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_4_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_4_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 14, 14, 256)  0           conv4_4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_4_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      activation_8[0][0]
# __________________________________________________________________________________________________
# conv4_4_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_4_3_conv[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 14, 14, 1024) 0           conv4_4_3_bn[0][0]
#                                                                  conv4_3_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_4_3_relu (Activation)     (None, 14, 14, 1024) 0           add_10[0][0]
# __________________________________________________________________________________________________
# conv4_5_1_conv (Conv2D)         (None, 14, 14, 256)  262400      conv4_4_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_5_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_5_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_5_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_5_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 256)  0           conv4_5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_5_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      activation_9[0][0]
# __________________________________________________________________________________________________
# conv4_5_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_5_3_conv[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 14, 14, 1024) 0           conv4_5_3_bn[0][0]
#                                                                  conv4_4_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_5_3_relu (Activation)     (None, 14, 14, 1024) 0           add_11[0][0]
# __________________________________________________________________________________________________
# conv4_6_1_conv (Conv2D)         (None, 14, 14, 256)  262400      conv4_5_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_6_1_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_6_1_relu (Activation)     (None, 14, 14, 256)  0           conv4_6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_2_conv (Conv2D)         (None, 14, 14, 256)  590080      conv4_6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_6_2_bn (BatchNormalizatio (None, 14, 14, 256)  1024        conv4_6_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 256)  0           conv4_6_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_6_3_conv (Conv2D)         (None, 14, 14, 1024) 263168      activation_10[0][0]
# __________________________________________________________________________________________________
# conv4_6_3_bn (BatchNormalizatio (None, 14, 14, 1024) 4096        conv4_6_3_conv[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 14, 14, 1024) 0           conv4_6_3_bn[0][0]
#                                                                  conv4_5_3_relu[0][0]
# __________________________________________________________________________________________________
# conv4_6_3_relu (Activation)     (None, 14, 14, 1024) 0           add_12[0][0]
# __________________________________________________________________________________________________
# conv5_1_1_conv (Conv2D)         (None, 7, 7, 512)    524800      conv4_6_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_1_1_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_1_1_relu (Activation)     (None, 7, 7, 512)    0           conv5_1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_1_2_conv (Conv2D)         (None, 7, 7, 512)    2359808     conv5_1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_1_2_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_1_2_relu (Activation)     (None, 7, 7, 512)    0           conv5_1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_1_3_conv (Conv2D)         (None, 7, 7, 2048)   1050624     conv5_1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_1_short_conv (Conv2D)     (None, 7, 7, 2048)   2099200     conv4_6_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_1_3_bn (BatchNormalizatio (None, 7, 7, 2048)   8192        conv5_1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_1_short_bn (BatchNormaliz (None, 7, 7, 2048)   8192        conv5_1_short_conv[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 7, 7, 2048)   0           conv5_1_3_bn[0][0]
#                                                                  conv5_1_short_bn[0][0]
# __________________________________________________________________________________________________
# conv5_1_3_relu (Activation)     (None, 7, 7, 2048)   0           add_13[0][0]
# __________________________________________________________________________________________________
# conv5_2_1_conv (Conv2D)         (None, 7, 7, 512)    1049088     conv5_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_2_1_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_2_1_relu (Activation)     (None, 7, 7, 512)    0           conv5_2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_2_2_conv (Conv2D)         (None, 7, 7, 512)    2359808     conv5_2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_2_2_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_2_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 512)    0           conv5_2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_2_3_conv (Conv2D)         (None, 7, 7, 2048)   1050624     activation_11[0][0]
# __________________________________________________________________________________________________
# conv5_2_3_bn (BatchNormalizatio (None, 7, 7, 2048)   8192        conv5_2_3_conv[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 7, 7, 2048)   0           conv5_2_3_bn[0][0]
#                                                                  conv5_1_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_2_3_relu (Activation)     (None, 7, 7, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# conv5_3_1_conv (Conv2D)         (None, 7, 7, 512)    1049088     conv5_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_3_1_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_3_1_relu (Activation)     (None, 7, 7, 512)    0           conv5_3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_3_2_conv (Conv2D)         (None, 7, 7, 512)    2359808     conv5_3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_3_2_bn (BatchNormalizatio (None, 7, 7, 512)    2048        conv5_3_2_conv[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 512)    0           conv5_3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_3_3_conv (Conv2D)         (None, 7, 7, 2048)   1050624     activation_12[0][0]
# __________________________________________________________________________________________________
# conv5_3_3_bn (BatchNormalizatio (None, 7, 7, 2048)   8192        conv5_3_3_conv[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 7, 7, 2048)   0           conv5_3_3_bn[0][0]
#                                                                  conv5_2_3_relu[0][0]
# __________________________________________________________________________________________________
# conv5_3_3_relu (Activation)     (None, 7, 7, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# avg_pool (AveragePooling2D)     (None, 3, 3, 2048)   0           conv5_3_3_relu[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 18432)        0           avg_pool[0][0]
# __________________________________________________________________________________________________
# fc_2 (Dense)                    (None, 1)            18433       flatten[0][0]
# ==================================================================================================
# Total params: 23,606,145
# Trainable params: 23,553,025
# Non-trainable params: 53,120
# __________________________________________________________________________________________________

# %%
import tensorflow

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers import RMSprop
opt = Adam(lr=0.0001)
model.compile(loss='binary_crossentropy',optimizer= opt, metrics=['accuracy'])
# Out:
# C:\Users\saidh\anaconda3\envs\tensorflow\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
from keras.callbacks import ModelCheckpoint
filepath = "saved-final-model.h5"
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
train_steps = 100000//100
valid_steps = 20000//100

history = model.fit_generator(
    train_flow,
    epochs =100,
    callbacks= callbacks_list,
    steps_per_epoch = train_steps,
    validation_data = valid_flow,
    validation_steps = valid_steps
)
# Out:
# Epoch 1/100
# 1000/1000 [==============================] - 672s 672ms/step - loss: 0.5401 - accuracy: 0.7254 - val_loss: 0.5423 - val_accuracy: 0.7252
#
# Epoch 00001: val_accuracy improved from 0.67172 to 0.72516, saving model to saved-final-model.h5
# Epoch 2/100
# 1000/1000 [==============================] - 658s 658ms/step - loss: 0.4992 - accuracy: 0.7547 - val_loss: 0.4942 - val_accuracy: 0.7571
#
# Epoch 00002: val_accuracy improved from 0.72516 to 0.75711, saving model to saved-final-model.h5
# Epoch 3/100
# 1000/1000 [==============================] - 642s 642ms/step - loss: 0.4666 - accuracy: 0.7759 - val_loss: 0.5066 - val_accuracy: 0.7532
#
# Epoch 00003: val_accuracy did not improve from 0.75711
# Epoch 4/100
# 1000/1000 [==============================] - 635s 635ms/step - loss: 0.4390 - accuracy: 0.7946 - val_loss: 0.5642 - val_accuracy: 0.7302
#
# Epoch 00004: val_accuracy did not improve from 0.75711
# Epoch 5/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.4092 - accuracy: 0.8123 - val_loss: 0.5139 - val_accuracy: 0.7573
#
# Epoch 00005: val_accuracy improved from 0.75711 to 0.75734, saving model to saved-final-model.h5
# Epoch 6/100
# 1000/1000 [==============================] - 650s 650ms/step - loss: 0.3890 - accuracy: 0.8229 - val_loss: 0.4445 - val_accuracy: 0.7920
#
# Epoch 00006: val_accuracy improved from 0.75734 to 0.79195, saving model to saved-final-model.h5
# Epoch 7/100
# 1000/1000 [==============================] - 657s 657ms/step - loss: 0.3679 - accuracy: 0.8341 - val_loss: 0.5340 - val_accuracy: 0.7592
#
# Epoch 00007: val_accuracy did not improve from 0.79195
# Epoch 8/100
# 1000/1000 [==============================] - 721s 721ms/step - loss: 0.3487 - accuracy: 0.8456 - val_loss: 0.4378 - val_accuracy: 0.7895
#
# Epoch 00008: val_accuracy did not improve from 0.79195
# Epoch 9/100
# 1000/1000 [==============================] - 688s 688ms/step - loss: 0.3282 - accuracy: 0.8559 - val_loss: 0.4407 - val_accuracy: 0.8055
#
# Epoch 00009: val_accuracy improved from 0.79195 to 0.80547, saving model to saved-final-model.h5
# Epoch 10/100
# 1000/1000 [==============================] - 669s 669ms/step - loss: 0.3153 - accuracy: 0.8622 - val_loss: 0.4585 - val_accuracy: 0.7977
#
# Epoch 00010: val_accuracy did not improve from 0.80547
# Epoch 11/100
# 1000/1000 [==============================] - 700s 700ms/step - loss: 0.2994 - accuracy: 0.8700 - val_loss: 0.3672 - val_accuracy: 0.8351
#
# Epoch 00011: val_accuracy improved from 0.80547 to 0.83508, saving model to saved-final-model.h5
# Epoch 12/100
# 1000/1000 [==============================] - 689s 689ms/step - loss: 0.2906 - accuracy: 0.8739 - val_loss: 0.4193 - val_accuracy: 0.8153
#
# Epoch 00012: val_accuracy did not improve from 0.83508
# Epoch 13/100
# 1000/1000 [==============================] - 762s 762ms/step - loss: 0.2759 - accuracy: 0.8820 - val_loss: 0.3424 - val_accuracy: 0.8518
#
# Epoch 00013: val_accuracy improved from 0.83508 to 0.85180, saving model to saved-final-model.h5
# Epoch 14/100
# 1000/1000 [==============================] - 671s 671ms/step - loss: 0.2661 - accuracy: 0.8860 - val_loss: 0.3444 - val_accuracy: 0.8573
#
# Epoch 00014: val_accuracy improved from 0.85180 to 0.85734, saving model to saved-final-model.h5
# Epoch 15/100
# 1000/1000 [==============================] - 705s 705ms/step - loss: 0.2577 - accuracy: 0.8903 - val_loss: 0.3819 - val_accuracy: 0.8416
#
# Epoch 00015: val_accuracy did not improve from 0.85734
# Epoch 16/100
# 1000/1000 [==============================] - 645s 645ms/step - loss: 0.2448 - accuracy: 0.8959 - val_loss: 0.4063 - val_accuracy: 0.8278
#
# Epoch 00016: val_accuracy did not improve from 0.85734
# Epoch 17/100
# 1000/1000 [==============================] - 629s 629ms/step - loss: 0.2339 - accuracy: 0.9018 - val_loss: 0.2938 - val_accuracy: 0.8789
#
# Epoch 00017: val_accuracy improved from 0.85734 to 0.87891, saving model to saved-final-model.h5
# Epoch 18/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.2278 - accuracy: 0.9036 - val_loss: 0.3726 - val_accuracy: 0.8449
#
# Epoch 00018: val_accuracy did not improve from 0.87891
# Epoch 19/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.2186 - accuracy: 0.9086 - val_loss: 0.3457 - val_accuracy: 0.8578
#
# Epoch 00019: val_accuracy did not improve from 0.87891
# Epoch 20/100
# 1000/1000 [==============================] - 634s 634ms/step - loss: 0.2130 - accuracy: 0.9107 - val_loss: 0.2416 - val_accuracy: 0.8991
#
# Epoch 00020: val_accuracy improved from 0.87891 to 0.89906, saving model to saved-final-model.h5
# Epoch 21/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.2064 - accuracy: 0.9146 - val_loss: 0.2282 - val_accuracy: 0.9023
#
# Epoch 00021: val_accuracy improved from 0.89906 to 0.90227, saving model to saved-final-model.h5
# Epoch 22/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.1998 - accuracy: 0.9161 - val_loss: 0.2747 - val_accuracy: 0.8879
#
# Epoch 00022: val_accuracy did not improve from 0.90227
# Epoch 23/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.1936 - accuracy: 0.9191 - val_loss: 0.2181 - val_accuracy: 0.9073
#
# Epoch 00023: val_accuracy improved from 0.90227 to 0.90734, saving model to saved-final-model.h5
# Epoch 24/100
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.1843 - accuracy: 0.9240 - val_loss: 0.3213 - val_accuracy: 0.8680
#
# Epoch 00024: val_accuracy did not improve from 0.90734
# Epoch 25/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1799 - accuracy: 0.9258 - val_loss: 0.2903 - val_accuracy: 0.8828
#
# Epoch 00025: val_accuracy did not improve from 0.90734
# Epoch 26/100
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.1781 - accuracy: 0.9273 - val_loss: 0.3000 - val_accuracy: 0.8774
#
# Epoch 00026: val_accuracy did not improve from 0.90734
# Epoch 27/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1719 - accuracy: 0.9294 - val_loss: 0.2534 - val_accuracy: 0.8957
#
# Epoch 00027: val_accuracy did not improve from 0.90734
# Epoch 28/100
# 1000/1000 [==============================] - 634s 634ms/step - loss: 0.1694 - accuracy: 0.9308 - val_loss: 0.1656 - val_accuracy: 0.9323
#
# Epoch 00028: val_accuracy improved from 0.90734 to 0.93234, saving model to saved-final-model.h5
# Epoch 29/100
# 1000/1000 [==============================] - 639s 639ms/step - loss: 0.1633 - accuracy: 0.9334 - val_loss: 0.2217 - val_accuracy: 0.9106
#
# Epoch 00029: val_accuracy did not improve from 0.93234
# Epoch 30/100
# 1000/1000 [==============================] - 636s 636ms/step - loss: 0.1608 - accuracy: 0.9339 - val_loss: 0.2988 - val_accuracy: 0.8823
#
# Epoch 00030: val_accuracy did not improve from 0.93234
# Epoch 31/100
# 1000/1000 [==============================] - 636s 636ms/step - loss: 0.1553 - accuracy: 0.9369 - val_loss: 0.2366 - val_accuracy: 0.9052
#
# Epoch 00031: val_accuracy did not improve from 0.93234
# Epoch 32/100
# 1000/1000 [==============================] - 645s 645ms/step - loss: 0.1512 - accuracy: 0.9388 - val_loss: 0.1511 - val_accuracy: 0.9410
#
# Epoch 00032: val_accuracy improved from 0.93234 to 0.94102, saving model to saved-final-model.h5
# Epoch 33/100
# 1000/1000 [==============================] - 639s 639ms/step - loss: 0.1478 - accuracy: 0.9397 - val_loss: 0.2885 - val_accuracy: 0.8915
#
# Epoch 00033: val_accuracy did not improve from 0.94102
# Epoch 34/100
# 1000/1000 [==============================] - 636s 636ms/step - loss: 0.1443 - accuracy: 0.9421 - val_loss: 0.2030 - val_accuracy: 0.9176
#
# Epoch 00034: val_accuracy did not improve from 0.94102
# Epoch 35/100
# 1000/1000 [==============================] - 634s 634ms/step - loss: 0.1448 - accuracy: 0.9409 - val_loss: 0.2078 - val_accuracy: 0.9156
#
# Epoch 00035: val_accuracy did not improve from 0.94102
# Epoch 36/100
# 1000/1000 [==============================] - 638s 638ms/step - loss: 0.1386 - accuracy: 0.9442 - val_loss: 0.2118 - val_accuracy: 0.9112
#
# Epoch 00036: val_accuracy did not improve from 0.94102
# Epoch 37/100
# 1000/1000 [==============================] - 641s 641ms/step - loss: 0.1347 - accuracy: 0.9470 - val_loss: 0.2379 - val_accuracy: 0.9055
#
# Epoch 00037: val_accuracy did not improve from 0.94102
# Epoch 38/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1367 - accuracy: 0.9444 - val_loss: 0.1908 - val_accuracy: 0.9237
#
# Epoch 00038: val_accuracy did not improve from 0.94102
# Epoch 39/100
# 1000/1000 [==============================] - 635s 635ms/step - loss: 0.1293 - accuracy: 0.9472 - val_loss: 0.1462 - val_accuracy: 0.9422
#
# Epoch 00039: val_accuracy improved from 0.94102 to 0.94219, saving model to saved-final-model.h5
# Epoch 40/100
# 1000/1000 [==============================] - 631s 631ms/step - loss: 0.1281 - accuracy: 0.9471 - val_loss: 0.2200 - val_accuracy: 0.9103
#
# Epoch 00040: val_accuracy did not improve from 0.94219
# Epoch 41/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1220 - accuracy: 0.9520 - val_loss: 0.1958 - val_accuracy: 0.9248
#
# Epoch 00041: val_accuracy did not improve from 0.94219
# Epoch 42/100
# 1000/1000 [==============================] - 634s 634ms/step - loss: 0.1234 - accuracy: 0.9496 - val_loss: 0.1522 - val_accuracy: 0.9396
#
# Epoch 00042: val_accuracy did not improve from 0.94219
# Epoch 43/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1193 - accuracy: 0.9523 - val_loss: 0.0994 - val_accuracy: 0.9621
#
# Epoch 00043: val_accuracy improved from 0.94219 to 0.96211, saving model to saved-final-model.h5
# Epoch 44/100
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.1160 - accuracy: 0.9536 - val_loss: 0.1909 - val_accuracy: 0.9236
#
# Epoch 00044: val_accuracy did not improve from 0.96211
# Epoch 45/100
# 1000/1000 [==============================] - 637s 637ms/step - loss: 0.1147 - accuracy: 0.9547 - val_loss: 0.1414 - val_accuracy: 0.9436
#
# Epoch 00045: val_accuracy did not improve from 0.96211
# Epoch 46/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1158 - accuracy: 0.9532 - val_loss: 0.1254 - val_accuracy: 0.9489
#
# Epoch 00046: val_accuracy did not improve from 0.96211
# Epoch 47/100
# 1000/1000 [==============================] - 635s 635ms/step - loss: 0.1137 - accuracy: 0.9544 - val_loss: 0.1923 - val_accuracy: 0.9245
#
# Epoch 00047: val_accuracy did not improve from 0.96211
# Epoch 48/100
# 1000/1000 [==============================] - 633s 633ms/step - loss: 0.1092 - accuracy: 0.9577 - val_loss: 0.1480 - val_accuracy: 0.9412
#
# Epoch 00048: val_accuracy did not improve from 0.96211
# Epoch 49/100
# 1000/1000 [==============================] - 636s 636ms/step - loss: 0.1079 - accuracy: 0.9562 - val_loss: 0.1728 - val_accuracy: 0.9313
#
# Epoch 00049: val_accuracy did not improve from 0.96211
# Epoch 50/100
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.1073 - accuracy: 0.9572 - val_loss: 0.1433 - val_accuracy: 0.9426
#
# Epoch 00050: val_accuracy did not improve from 0.96211
# Epoch 51/100
# 1000/1000 [==============================] - 640s 640ms/step - loss: 0.1040 - accuracy: 0.9592 - val_loss: 0.1184 - val_accuracy: 0.9527
#
# Epoch 00051: val_accuracy did not improve from 0.96211
# Epoch 52/100
# 1000/1000 [==============================] - 632s 632ms/step - loss: 0.1058 - accuracy: 0.9580 - val_loss: 0.1246 - val_accuracy: 0.9528
#
# Epoch 00052: val_accuracy did not improve from 0.96211
# Epoch 53/100
# 1000/1000 [==============================] - 639s 639ms/step - loss: 0.0997 - accuracy: 0.9601 - val_loss: 0.1411 - val_accuracy: 0.9446
#
# Epoch 00053: val_accuracy did not improve from 0.96211
# Epoch 54/100
# 1000/1000 [==============================] - 685s 685ms/step - loss: 0.0974 - accuracy: 0.9615 - val_loss: 0.1587 - val_accuracy: 0.9392
#
# Epoch 00054: val_accuracy did not improve from 0.96211
# Epoch 55/100
# 1000/1000 [==============================] - 635s 635ms/step - loss: 0.0971 - accuracy: 0.9607 - val_loss: 0.0900 - val_accuracy: 0.9638
#
# Epoch 00055: val_accuracy improved from 0.96211 to 0.96375, saving model to saved-final-model.h5
# Epoch 56/100
# 1000/1000 [==============================] - 649s 649ms/step - loss: 0.0972 - accuracy: 0.9606 - val_loss: 0.2259 - val_accuracy: 0.9094
#
# Epoch 00056: val_accuracy did not improve from 0.96375
# Epoch 57/100
# 1000/1000 [==============================] - 636s 636ms/step - loss: 0.0983 - accuracy: 0.9614 - val_loss: 0.0947 - val_accuracy: 0.9641
#
# Epoch 00057: val_accuracy improved from 0.96375 to 0.96414, saving model to saved-final-model.h5
# Epoch 58/100
# 1000/1000 [==============================] - 635s 635ms/step - loss: 0.0914 - accuracy: 0.9639 - val_loss: 0.0959 - val_accuracy: 0.9611
#
# Epoch 00058: val_accuracy did not improve from 0.96414
# Epoch 59/100
# 1000/1000 [==============================] - 652s 652ms/step - loss: 0.0941 - accuracy: 0.9633 - val_loss: 0.1060 - val_accuracy: 0.9598
#
# Epoch 00059: val_accuracy did not improve from 0.96414
# Epoch 60/100
# 1000/1000 [==============================] - 648s 648ms/step - loss: 0.0922 - accuracy: 0.9639 - val_loss: 0.0891 - val_accuracy: 0.9640
#
# Epoch 00060: val_accuracy did not improve from 0.96414
# Epoch 61/100
# 1000/1000 [==============================] - 641s 641ms/step - loss: 0.0892 - accuracy: 0.9645 - val_loss: 0.1342 - val_accuracy: 0.9470
#
# Epoch 00061: val_accuracy did not improve from 0.96414
# Epoch 62/100
# 1000/1000 [==============================] - 642s 642ms/step - loss: 0.0895 - accuracy: 0.9639 - val_loss: 0.1671 - val_accuracy: 0.9341
#
# Epoch 00062: val_accuracy did not improve from 0.96414
# Epoch 63/100
# 1000/1000 [==============================] - 639s 639ms/step - loss: 0.0860 - accuracy: 0.9656 - val_loss: 0.0831 - val_accuracy: 0.9692
#
# Epoch 00063: val_accuracy improved from 0.96414 to 0.96922, saving model to saved-final-model.h5
# Epoch 64/100
# 1000/1000 [==============================] - 699s 699ms/step - loss: 0.0887 - accuracy: 0.9651 - val_loss: 0.1759 - val_accuracy: 0.9345
#
# Epoch 00064: val_accuracy did not improve from 0.96922
# Epoch 65/100
# 1000/1000 [==============================] - 730s 730ms/step - loss: 0.0825 - accuracy: 0.9674 - val_loss: 0.0950 - val_accuracy: 0.9643
#
# Epoch 00065: val_accuracy did not improve from 0.96922
# Epoch 66/100
# 1000/1000 [==============================] - 756s 756ms/step - loss: 0.0860 - accuracy: 0.9655 - val_loss: 0.0926 - val_accuracy: 0.9630
#
# Epoch 00066: val_accuracy did not improve from 0.96922
# Epoch 67/100
# 1000/1000 [==============================] - 767s 767ms/step - loss: 0.0838 - accuracy: 0.9669 - val_loss: 0.1128 - val_accuracy: 0.9566
#
# Epoch 00067: val_accuracy did not improve from 0.96922
# Epoch 68/100
# 1000/1000 [==============================] - 748s 748ms/step - loss: 0.0822 - accuracy: 0.9677 - val_loss: 0.1338 - val_accuracy: 0.9500
#
# Epoch 00068: val_accuracy did not improve from 0.96922
# Epoch 69/100
# 1000/1000 [==============================] - 730s 730ms/step - loss: 0.0790 - accuracy: 0.9686 - val_loss: 0.2143 - val_accuracy: 0.9159
#
# Epoch 00069: val_accuracy did not improve from 0.96922
# Epoch 70/100
# 1000/1000 [==============================] - 777s 777ms/step - loss: 0.0814 - accuracy: 0.9681 - val_loss: 0.1097 - val_accuracy: 0.9578
#
# Epoch 00070: val_accuracy did not improve from 0.96922
# Epoch 71/100
# 1000/1000 [==============================] - 790s 790ms/step - loss: 0.0779 - accuracy: 0.9687 - val_loss: 0.1077 - val_accuracy: 0.9580
#
# Epoch 00071: val_accuracy did not improve from 0.96922
# Epoch 72/100
# 1000/1000 [==============================] - 829s 829ms/step - loss: 0.0788 - accuracy: 0.9686 - val_loss: 0.2353 - val_accuracy: 0.9159
#
# Epoch 00072: val_accuracy did not improve from 0.96922
# Epoch 73/100
# 1000/1000 [==============================] - 769s 769ms/step - loss: 0.0797 - accuracy: 0.9690 - val_loss: 0.1010 - val_accuracy: 0.9617
#
# Epoch 00073: val_accuracy did not improve from 0.96922
# Epoch 74/100
# 1000/1000 [==============================] - 742s 742ms/step - loss: 0.0761 - accuracy: 0.9704 - val_loss: 0.0894 - val_accuracy: 0.9657
#
# Epoch 00074: val_accuracy did not improve from 0.96922
# Epoch 75/100
# 1000/1000 [==============================] - 744s 744ms/step - loss: 0.0779 - accuracy: 0.9698 - val_loss: 0.0698 - val_accuracy: 0.9734
#
# Epoch 00075: val_accuracy improved from 0.96922 to 0.97344, saving model to saved-final-model.h5
# Epoch 76/100
# 1000/1000 [==============================] - 746s 746ms/step - loss: 0.0744 - accuracy: 0.9708 - val_loss: 0.0950 - val_accuracy: 0.9610
# Epoch 00076: val_accuracy did not improve from 0.97344
# Epoch 77/100
# 1000/1000 [==============================] - 745s 745ms/step - loss: 0.0743 - accuracy: 0.9713 - val_loss: 0.1796 - val_accuracy: 0.9317
#
# Epoch 00077: val_accuracy did not improve from 0.97344
# Epoch 78/100
# 1000/1000 [==============================] - 762s 762ms/step - loss: 0.0738 - accuracy: 0.9701 - val_loss: 0.1407 - val_accuracy: 0.9441
#
# Epoch 00078: val_accuracy did not improve from 0.97344
# Epoch 79/100
# 1000/1000 [==============================] - 873s 873ms/step - loss: 0.0711 - accuracy: 0.9723 - val_loss: 0.1253 - val_accuracy: 0.9514
#
# Epoch 00079: val_accuracy did not improve from 0.97344
# Epoch 80/100
# 1000/1000 [==============================] - 748s 748ms/step - loss: 0.0734 - accuracy: 0.9710 - val_loss: 0.0778 - val_accuracy: 0.9698
#
# Epoch 00080: val_accuracy did not improve from 0.97344
# Epoch 81/100
# 1000/1000 [==============================] - 836s 836ms/step - loss: 0.0739 - accuracy: 0.9712 - val_loss: 0.0983 - val_accuracy: 0.9629
#
# Epoch 00081: val_accuracy did not improve from 0.97344
# Epoch 82/100
# 1000/1000 [==============================] - 1112s 1s/step - loss: 0.0695 - accuracy: 0.9733 - val_loss: 0.1965 - val_accuracy: 0.9227
#
# Epoch 00082: val_accuracy did not improve from 0.97344
# Epoch 83/100
# 1000/1000 [==============================] - 915s 915ms/step - loss: 0.0700 - accuracy: 0.9723 - val_loss: 0.1372 - val_accuracy: 0.9489
#
# Epoch 00083: val_accuracy did not improve from 0.97344
# Epoch 84/100
# 1000/1000 [==============================] - 798s 798ms/step - loss: 0.0705 - accuracy: 0.9716 - val_loss: 0.0963 - val_accuracy: 0.9634
#
# Epoch 00084: val_accuracy did not improve from 0.97344
# Epoch 85/100
# 1000/1000 [==============================] - 847s 847ms/step - loss: 0.0692 - accuracy: 0.9731 - val_loss: 0.1484 - val_accuracy: 0.9423
#
# Epoch 00085: val_accuracy did not improve from 0.97344
# Epoch 86/100
# 1000/1000 [==============================] - 837s 837ms/step - loss: 0.0672 - accuracy: 0.9737 - val_loss: 0.0735 - val_accuracy: 0.9722
#
# Epoch 00086: val_accuracy did not improve from 0.97344
# Epoch 87/100
# 1000/1000 [==============================] - 850s 850ms/step - loss: 0.0680 - accuracy: 0.9735 - val_loss: 0.1969 - val_accuracy: 0.9251
#
# Epoch 00087: val_accuracy did not improve from 0.97344
# Epoch 88/100
# 1000/1000 [==============================] - 753s 753ms/step - loss: 0.0652 - accuracy: 0.9749 - val_loss: 0.0868 - val_accuracy: 0.9663
#
# Epoch 00088: val_accuracy did not improve from 0.97344
# Epoch 89/100
# 1000/1000 [==============================] - 772s 772ms/step - loss: 0.0643 - accuracy: 0.9750 - val_loss: 0.0676 - val_accuracy: 0.9734
#
# Epoch 00089: val_accuracy did not improve from 0.97344
# Epoch 90/100
# 1000/1000 [==============================] - 773s 773ms/step - loss: 0.0632 - accuracy: 0.9759 - val_loss: 0.0789 - val_accuracy: 0.9700
#
# Epoch 00090: val_accuracy did not improve from 0.97344
# Epoch 91/100
# 1000/1000 [==============================] - 758s 758ms/step - loss: 0.0642 - accuracy: 0.9741 - val_loss: 0.1030 - val_accuracy: 0.9606
#
# Epoch 00091: val_accuracy did not improve from 0.97344
# Epoch 92/100
# 1000/1000 [==============================] - 752s 752ms/step - loss: 0.0663 - accuracy: 0.9745 - val_loss: 0.0710 - val_accuracy: 0.9718
#
# Epoch 00092: val_accuracy did not improve from 0.97344
# Epoch 93/100
# 1000/1000 [==============================] - 795s 795ms/step - loss: 0.0635 - accuracy: 0.9753 - val_loss: 0.1413 - val_accuracy: 0.9468
#
# Epoch 00093: val_accuracy did not improve from 0.97344
# Epoch 94/100
# 1000/1000 [==============================] - 798s 798ms/step - loss: 0.0618 - accuracy: 0.9757 - val_loss: 0.0913 - val_accuracy: 0.9646
#
# Epoch 00094: val_accuracy did not improve from 0.97344
# Epoch 95/100
# 1000/1000 [==============================] - 857s 857ms/step - loss: 0.0613 - accuracy: 0.9766 - val_loss: 0.0737 - val_accuracy: 0.9702
#
# Epoch 00095: val_accuracy did not improve from 0.97344
# Epoch 96/100
# 1000/1000 [==============================] - 919s 919ms/step - loss: 0.0598 - accuracy: 0.9773 - val_loss: 0.0601 - val_accuracy: 0.9782
#
# Epoch 00096: val_accuracy improved from 0.97344 to 0.97820, saving model to saved-final-model.h5
# Epoch 97/100
# 1000/1000 [==============================] - 977s 977ms/step - loss: 0.0632 - accuracy: 0.9754 - val_loss: 0.1028 - val_accuracy: 0.9593
#
# Epoch 00097: val_accuracy did not improve from 0.97820
# Epoch 98/100
# 1000/1000 [==============================] - 1002s 1s/step - loss: 0.0588 - accuracy: 0.9770 - val_loss: 0.0990 - val_accuracy: 0.9634
#
# Epoch 00098: val_accuracy did not improve from 0.97820
# Epoch 99/100
# 1000/1000 [==============================] - 867s 867ms/step - loss: 0.0602 - accuracy: 0.9768 - val_loss: 0.0824 - val_accuracy: 0.9695
#
# Epoch 00099: val_accuracy did not improve from 0.97820
# Epoch 100/100
# 1000/1000 [==============================] - 765s 765ms/step - loss: 0.0600 - accuracy: 0.9765 - val_loss: 0.0830 - val_accuracy: 0.9679
#
# Epoch 00100: val_accuracy did not improve from 0.97820

# %% [markdown]
# # ---------------------------------------------------------------------------------------------------------------

# %%
# # Parameters Initialization
# from tensorflow.keras.optimizers import SGD,Adam,Adadelta
# import keras
# #opt = rmsprop(lr=0.0001, decay=1e-6)

# model.compile(loss='binary_crossentropy',optimizer=Adam(0.0001), metrics=['accuracy'])

# %%
# from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
# import os

# %%
# save_dir = os.path.join(os.getcwd(), 'saved_models')
# model_name = 'cifar10_resnet_model.h5'
# if not os.path.isdir(save_dir):
#     os.makedirs(save_dir)
# filepath = os.path.join(save_dir, model_name)

# %%
# checkpoint = ModelCheckpoint(filepath=filepath,
#                              verbose=1,
#                              save_best_only=True)
# lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
#                                cooldown=0,
#                                patience=5,
#                                min_lr=0.5e-6)
# callbacks = [checkpoint, lr_reducer]

# %%
# data_augmentation = True
# random_erasing = True
# pixel_level = False

# %%
# if not data_augmentation:
#     print('Not using data augmentation.')
#     model.fit(x_train, y_train,
#               batch_size=batch_size,
#               epochs=epochs,
#               validation_data=(x_test, y_test),
#               shuffle=True,
#               callbacks=callbacks)
# else:
#     print('Using real-time data augmentation.')
#     # This will do preprocessing and realtime data augmentation:
#     datagen = ImageDataGenerator(
#         featurewise_center=False,  # set input mean to 0 over the dataset
#         samplewise_center=False,  # set each sample mean to 0
#         featurewise_std_normalization=False,  # divide inputs by std of the dataset
#         samplewise_std_normalization=False,  # divide each input by its std
#         zca_whitening=False,  # apply ZCA whitening
#         rotation_range=0,  # randomly rotate images in the range (degrees, 0 to 180)
#         width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
#         height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
#         horizontal_flip=True,  # randomly flip images
#         vertical_flip=False,  # randomly flip images
#         preprocessing_function=get_random_eraser(v_l=0, v_h=1, pixel_level=pixel_level))
#     datagen.fit(train_flow)

#     # Fit the model on the batches generated by datagen.flow().
#     model.fit_generator(datagen.flow(train_flow, y_train, batch_size=batch_size),
#                         steps_per_epoch=x_train.shape[0] // batch_size,
#                         validation_data=(x_test, y_test),
#                         epochs=epochs, verbose=1, workers=4,
#                         callbacks=callbacks)

# %%
# train_steps = 40000//batch_size
# valid_steps = 5000//batch_size
# history = model.fit_generator(
#     train_flow,
#     epochs=10,
#     steps_per_epoch=train_steps,
#     validation_data=valid_flow,
#     validation_steps=valid_steps
# )
# Out:
# C:\Users\saidh\anaconda3\envs\tensorflow\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/10
# 625/625 [==============================] - 2093s 3s/step - loss: 0.7270 - accuracy: 0.6190 - val_loss: 0.6808 - val_accuracy: 0.6266
# Epoch 2/10
# 625/625 [==============================] - 2002s 3s/step - loss: 0.6299 - accuracy: 0.6658 - val_loss: 0.6858 - val_accuracy: 0.6356
# Epoch 3/10
# 625/625 [==============================] - 1998s 3s/step - loss: 0.5940 - accuracy: 0.6918 - val_loss: 0.6417 - val_accuracy: 0.6585
# Epoch 4/10
# 625/625 [==============================] - 1864s 3s/step - loss: 0.5706 - accuracy: 0.7095 - val_loss: 0.5952 - val_accuracy: 0.6977
# Epoch 5/10
# 625/625 [==============================] - 2019s 3s/step - loss: 0.5450 - accuracy: 0.7268 - val_loss: 0.5832 - val_accuracy: 0.7057
# Epoch 6/10
# 625/625 [==============================] - 1971s 3s/step - loss: 0.5154 - accuracy: 0.7454 - val_loss: 0.6104 - val_accuracy: 0.6993
# Epoch 7/10
# 625/625 [==============================] - 1936s 3s/step - loss: 0.5025 - accuracy: 0.7556 - val_loss: 0.5069 - val_accuracy: 0.7532
# Epoch 8/10
# 625/625 [==============================] - 2057s 3s/step - loss: 0.4819 - accuracy: 0.7704 - val_loss: 0.6691 - val_accuracy: 0.6743
# Epoch 9/10
# 625/625 [==============================] - 2069s 3s/step - loss: 0.4644 - accuracy: 0.7800 - val_loss: 0.4742 - val_accuracy: 0.7798
# Epoch 10/10
# 625/625 [==============================] - 1981s 3s/step - loss: 0.4443 - accuracy: 0.7931 - val_loss: 0.5393 - val_accuracy: 0.7444

# %%
model.save("custom_augmented_model.h5")

# %%
"""
Plot the training and validation loss
epochs - list of epoch numbers
loss - training loss for each epoch
val_loss - validation loss for each epoch
"""
def plot_loss(epochs, loss, val_loss):
    plt.plot(epochs, loss, 'bo', label='Training Loss')
    plt.plot(epochs, val_loss, 'orange', label = 'Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.show()
"""
Plot the training and validation accuracy
epochs - list of epoch numbers
acc - training accuracy for each epoch
val_acc - validation accuracy for each epoch
"""
def plot_accuracy(epochs, acc, val_acc):
    plt.plot(epochs, acc, 'bo', label='Training accuracy')
    plt.plot(epochs, val_acc, 'orange', label = 'Validation accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.show()

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plot_loss(range(1, len(loss) + 1), loss, val_loss)
plot_accuracy(range(1, len(loss) + 1), acc, val_acc)

# %%
plt.plot(history.history['loss'], label='train loss')
plt.plot(history.history['val_loss'], label='val loss')
plt.legend()
plt.show()
plt.savefig('LossVal_loss')

# plot the accuracy
plt.plot(history.history['accuracy'], label='train acc')
plt.plot(history.history['val_accuracy'], label='val acc')
plt.legend()
plt.show()

# %%
test_flow = image_gen1.flow_from_directory(
    base_path + 'test/',
    target_size = (224, 224),
    batch_size = 1,
    shuffle = False,
    class_mode ='binary'
)
# Out:
# Found 20000 images belonging to 2 classes.

# %%
y_pred = model.predict(test_flow)
y_test = test_flow.classes

# %%
from sklearn import metrics

# %%
print("ROC AUC Score:", metrics.roc_auc_score(y_test, y_pred))
print("AP Score:", metrics.average_precision_score(y_test, y_pred))
print()
print(metrics.classification_report(y_test, y_pred > 0.5))
# Out:
# ROC AUC Score: 0.99843864
# AP Score: 0.9984253126993125
#
#               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97     10000
#            1       0.99      0.94      0.97     10000
#
#     accuracy                           0.97     20000
#    macro avg       0.97      0.97      0.97     20000
# weighted avg       0.97      0.97      0.97     20000

# %%
y_test
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
y_test1 = np.array(y_test)
y_test1
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
y_pred
# Out:
# array([[3.0904166e-06],
#        [1.1434428e-07],
#        [5.4451216e-02],
#        ...,
#        [8.9957589e-01],
#        [9.9395627e-01],
#        [9.9993587e-01]], dtype=float32)

# %%
y_pred1 = y_pred.copy()
np.where(y_pred1 > 0.5, 1, 0)
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [1],
#        [1],
#        [1]])

# %%
y_pred2 = y_pred1.flatten()
y_pred2 = np.where(y_pred2 > 0.5, 1, 0)
y_pred2
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred2)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[9951   49]
#  [ 606 9394]]
# acc: 0.9673
# sensitivity: 0.9951
# specificity: 0.9394

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test,y_pred2)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# [[9951   49]
#  [ 606 9394]]
# acc: 0.9673
# sensitivity: 0.9951
# specificity: 0.9394

# %%
import seaborn as sns
sns.heatmap(cm,annot=True, fmt='g')
# Out:
# <AxesSubplot:>
